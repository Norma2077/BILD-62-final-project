# %%
import pandas as pd
df_proteinC = pd.read_csv('color.csv')
df_proteinC.head()
# Out:
#   Color  Protein  Excitation Maximum(nm)  Emission Maximum  \
# 0  blue     EBFP                     383               445
# 1  blue    EBFP2                     383               448
# 2  blue  Azurite                     384               450
# 3  blue  mTagBFP                     399               456
# 4  cyan     ECFP                     439               476
#
#    wavelength max(nm)  wavelength min(nm)
# 0                 495                 450
# 1                 495                 450
# 2                 495                 450
# 3                 495                 450
# 4                 520                 490

# %%
row_index = 'Color'
df_proteinC = df_proteinC.set_index(row_index)
df_proteinC.head(57)
# Out:
#                    Protein  Excitation Maximum(nm)  Emission Maximum  \
# Color
# blue                  EBFP                     383               445
# blue                 EBFP2                     383               448
# blue               Azurite                     384               450
# blue               mTagBFP                     399               456
# cyan                  ECFP                     439               476
# cyan                 mECFP                     433               475
# cyan              Cerulean                     433               475
# cyan                 CyPet                     435               477
# cyan               AmCyan1                     458               489
# cyan      Midori-Ishi Cyan                     472               495
# cyan                TagCFP                     458               480
# cyan          mTFP1 (Teal)                     462               492
# ...

# %%
df_proteinC_green = df_proteinC.loc['green']
df_proteinC_yellow = df_proteinC.loc['yellow']
df_proteinC_green.to_csv('green.csv', index=False)
df_proteinC_yellow.to_csv('yellow.csv', index=False)
df_proteinC_yellow
df_proteinC_green
# Out:
#                Protein  Excitation Maximum(nm)  Emission Maximum  \
# Color
# green             EGFP                     484               507
# green          Emerald                     487               509
# green  Superfolder GFP                     485               510
# green      Azami Green                     492               505
# green          mWasabi                     493               509
# green           TagGFP                     482               505
# green         TurboGFP                     482               502
# green            AcGFP                     480               505
# green          ZsGreen                     493               505
# green       T-Sapphire                     399               511
#
#        wavelength max(nm)  wavelength min(nm)
# Color
# green                 570                 495
# green                 570                 495
# green                 570                 495
# green                 570                 495
# ...
